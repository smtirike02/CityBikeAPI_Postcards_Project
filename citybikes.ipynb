# %%
import requests
import json
import pybikes
import numpy as np
import pandas
import collections

# %%
headers = {'Accept': 'application/json'}
r = requests.get('http://api.citybik.es/v2/networks', headers=headers)

# Convert data to JSON format
data = r.json()
#client = citybikes.Client()

# Extract the info and records
networks = data['networks']
location = data ['networks']

# %%
print(data)

# %%
#networks = list(client.networks)
#len(networks) # number of bike networks

# %%
 networks[0] # networks of bikes stations of cities (type diff num for diff network)
# Out:
# {'company': ['ЗАО «СитиБайк»'],
#  'href': '/v2/networks/velobike-moscow',
#  'id': 'velobike-moscow',
#  'location': {'city': 'Moscow',
#   'country': 'RU',
#   'latitude': 55.75,
#   'longitude': 37.616667},
#  'name': 'Velobike'}

# %%
for networks in data['networks']:
    print(networks['location'])
# Out:
# {'city': 'Moscow', 'country': 'RU', 'latitude': 55.75, 'longitude': 37.616667}
# {'city': 'Bærum', 'country': 'NO', 'latitude': 59.89455, 'longitude': 10.546343}
# {'city': 'Siena', 'country': 'IT', 'latitude': 43.3186, 'longitude': 11.3306}
# {'city': 'Maroussi', 'country': 'GR', 'latitude': 38.0568722388, 'longitude': 23.8083299536}
# {'city': 'Slough', 'country': 'GB', 'latitude': 51.51135, 'longitude': -0.591562}
# {'city': 'Nafplio', 'country': 'GR', 'latitude': 37.5639397319, 'longitude': 22.8093402872}
# {'city': 'Parco dei Colli di Bergamo', 'country': 'IT', 'latitude': 45.72295637032245, 'longitude': 9.649230073016383}
# {'city': 'Aigialeia', 'country': 'GR', 'latitude': 38.2511101325, 'longitude': 22.0821570196}
# {'city': 'Marathon', 'country': 'GR', 'latitude': 38.0855680022, 'longitude': 23.9776389963}
# {'city': 'Mantova', 'country': 'IT', 'latitude': 45.15866370764634, 'longitude': 10.783718973016335}
# ...

# %%
#http://api.citybik.es/v2/networks/velib
#http://api.citybik.es/v2/networks?fields=location

r = requests.get('http://api.citybik.es/v2/networks?fields=location')
# Convert data to JSON format
data = r.json()
networks = data ['networks']
#networks = list(client.networks)
print(data)
# Out:
# {'networks': [{'company': ['ЗАО «СитиБайк»'], 'href': '/v2/networks/velobike-moscow', 'id': 'velobike-moscow', 'location': {'city': 'Moscow', 'country': 'RU', 'latitude': 55.75, 'longitude': 37.616667}, 'name': 'Velobike'}, {'company': ['Urban Infrastructure Partner'], 'href': '/v2/networks/baerum-bysykkel', 'id': 'baerum-bysykkel', 'location': {'city': 'Bærum', 'country': 'NO', 'latitude': 59.89455, 'longitude': 10.546343}, 'name': 'Bysykkel'}, {'company': ['Comunicare S.r.l.'], 'href': '/v2/networks/bicincitta-siena', 'id': 'bicincitta-siena', 'location': {'city': 'Siena', 'country': 'IT', 'latitude': 43.3186, 'longitude': 11.3306}, 'name': 'Bicincittà', 'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=202'}, {'company': ['Cyclopolis Systems'], 'href': '/v2/networks/cyclopolis-maroussi', 'id': 'cyclopolis-maroussi', 'location': {'city': 'Maroussi', 'country': 'GR', 'latitude': 38.0568722388, 'longitude': 23.8083299536}, 'name': 'Cyclopolis'}, {'company': ['Groundwork', '
# ...

# %%
from collections import Counter

# Sort the networks by country
networks_by_country = sorted(data["networks"], key=lambda x: x["location"]["country"])

# Print the networks alphabetically by country
for network in networks_by_country:
    print(network["location"]["country"], network["location"]["city"])
    
    #1.sort out the data alphabetically  /done
    #2.see from data how many bike stations within that country /done
    #see if theres a correlation between how many bike stations and better infrastructure within that city 
     
#AE,AR,AT,AU,BA,BE,BR,CA,CH,CL,C0,CY,CZ,DE,ES,FI,FR,GB,GR,HR,HU,IE,IL,IN,IS,IT,JP,KZ,LB,LT,LU,LV,MC,ME.MT,MX,NL,NO,PL,R0,RU,SE,SI,SK,TH,TR,UA,US
#top four germany,Czech Republic,Switzerland,france

#collected data that has the most bike networks within that country
#going to look at the most countries with the most networks
#im going to illustrate the data of the cities within the countries
# Out:
# AE Abu Dhabi
# AR Buenos Aires
# AR Rosario
# AT Neusiedler See
# AT St.Pölten
# AT Mödling
# AT Wachau
# AT Tulln
# AT Thermenregion
# AT Wr.Neustadt
# AT 10vorWien
# AT Innsbruck
# AT Hollabrunn
# AT WienerWald
# AT Serfaus
# AT Groß Enzersdorf
# AT Klagenfurt
# AT Wien
# AT Linz
# AT Kufstein
# AT Ellmau
# AU Curtin University, Perth, WA
# AU Melbourne, AU
# AU Melbourne
# BA Sarajevo
# BA Tuzla
# BA Banja Luka
# BE Antwerpen
# BE Namur
# BE Bruxelles
# BE Gent
# BR São Paulo
# BR Recife
# BR São Paulo
# BR Rio de Janeiro
# BR Salvador
# BR Porto Alegre
# BR Sorocaba
# BR São Lourenço
# BR Ipaússu
# BR Belo Horizonte
# BR Petrolina
# BR Brasília
# BR Goiânia
# BR Fortaleza
# BR Aracajú
# BR Belém
# BR Santos
# CA Montréal, QC
# CA Toronto, ON
# CA Hamilton, ON
# CA Vancouver
# CA Québec
# CA Saguenay
# CH Sursee
# CH Luzern
# CH Hergiswil
# CH Stans
# CH Stansstad
# CH Horw
# CH Sarnen
# CH Wolfenschiessen
# CH Oberdorf
# CH Ennetmoos
# CH Zürich
# CH Sierre
# CH Nyon
# CH Bern
# ...

# %%
z = ["AE", "AR", "AR", "AT", "AT", "AT", "AT", "AT", "AT", "AT", "AT", "AT", "AT", "AT", "AT", "AT", "AT", "AT", "AT", "AT", "AT", "AU", "AU", "AU", "BA", "BA", "BA", "BE", "BE", "BE", "BE", "BR", "BR", "BR", "BR", "BR", "BR", "BR", "BR", "BR", "BR", "BR", "BR", "BR", "BR", "BR", "BR", "BR", "CA", "CA", "CA", "CA", "CA", "CA", "CH", "CH", "CH", "CH", "CH", "CH", "CH", "CH", "CH", "CH", "CH", "CH", "CH", "CH", "CH", "CH", "CH", "CH", "CL", "CL", "CO", "CY", "CY", "CY", "CZ", "CZ", "CZ", "CZ", "CZ", "CZ", "CZ", "CZ", "CZ", "CZ", "CZ", "CZ", "CZ", "CZ", "CZ", "CZ", "CZ", "CZ", "CZ", "CZ", "CZ", "CZ", "CZ", "CZ", "CZ", "CZ", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "DE", "ES", "ES", "ES", "ES", "ES", "ES", "ES", "ES", "ES", "ES", "ES", "ES", "ES", "ES", "ES", "ES", "ES", "ES", "ES", "ES", "ES", "ES", "ES", "ES", "ES", "ES", "FI", "FI", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "FR", "GB", "GB", "GB", "GB", "GB", "GB", "GB", "GB", "GB", "GB", "GB", "GE", "GR", "GR", "GR", "GR", "GR", "GR", "GR", "GR", "GR", "GR", "GR", "GR", "GR", "GR", "GR", "GR", "GR", "GR", "GR", "GR", "GR", "GR", "GR", "GR", "GR", "GR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HR", "HU", "IE", "IE", "IE", "IE", "IL", "IN", "IS", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "IT", "JP", "KZ", "KZ", "KZ", "LB", "LT", "LU", "LU", "LV", "MC", "ME", "MT", "MX", "MX", "MX", "MX", "NL", "NL", "NO", "NO", "NO", "NO", "NO", "NZ", "NZ", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PL", "PT", "RO", "RO", "RO", "RO", "RU", "RU", "RU", "SE", "SE", "SE", "SI", "SI", "SI", "SI", "SI", "SI", "SI", "SI", "SI", "SK", "SK", "SK", "SK", "SK", "TH", "TR", "TR", "TR", "TR", "UA", "UA", "UA", "UA", "UK", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US", "US"]

# %%
Counter(z) #shows the highest usage of bikes in a country.
#italy (IT) -123
# germany (DE) - 73
# Poland (PL) 55
# United States (50) (US) - Country
#suprised at the US data since the US doesn't priortise bikes and paedestinisation
# Out:
# Counter({'AE': 1,
#          'AR': 2,
#          'AT': 18,
#          'AU': 3,
#          'BA': 3,
#          'BE': 4,
#          'BR': 17,
#          'CA': 6,
#          'CH': 18,
#          'CL': 2,
#          'CO': 1,
#          'CY': 3,
#          'CZ': 26,
#          'DE': 73,
#          'ES': 26,
#          'FI': 2,
#          'FR': 44,
#          'GB': 11,
#          'GE': 1,
#          'GR': 26,
#          'HR': 28,
#          'HU': 1,
#          'IE': 4,
#          'IL': 1,
#          'IN': 1,
#          'IS': 1,
#          'IT': 123,
#          'JP': 1,
#          'KZ': 3,
#          'LB': 1,
#          'LT': 1,
#          'LU': 2,
#          'LV': 1,
#          'MC': 1,
#          'ME': 1,
#          'MT': 1,
#          'MX': 4,
#          'NL': 2,
#          'NO': 5,
#          'NZ': 2,
#          'PL': 55,
#          'PT': 1,
#          'RO': 4,
#          'RU': 3,
#          'SE': 3,
#          'SI': 9,
#          'SK': 5,
#          'TH': 1,
#          'TR': 4,
# ...

# %%
c = collections.Counter(z)
print(c)
print(c.most_common()) #sorts countries from highest to lowest
# Out:
# Counter({'IT': 123, 'DE': 73, 'PL': 55, 'US': 50, 'FR': 44, 'HR': 28, 'CZ': 26, 'ES': 26, 'GR': 26, 'AT': 18, 'CH': 18, 'BR': 17, 'GB': 11, 'SI': 9, 'CA': 6, 'NO': 5, 'SK': 5, 'BE': 4, 'IE': 4, 'MX': 4, 'RO': 4, 'TR': 4, 'UA': 4, 'AU': 3, 'BA': 3, 'CY': 3, 'KZ': 3, 'RU': 3, 'SE': 3, 'AR': 2, 'CL': 2, 'FI': 2, 'LU': 2, 'NL': 2, 'NZ': 2, 'AE': 1, 'CO': 1, 'GE': 1, 'HU': 1, 'IL': 1, 'IN': 1, 'IS': 1, 'JP': 1, 'LB': 1, 'LT': 1, 'LV': 1, 'MC': 1, 'ME': 1, 'MT': 1, 'PT': 1, 'TH': 1, 'UK': 1})
# ...

# %%
r = requests.get('http://api.citybik.es/v2/networks')
# Convert data to JSON format
data = r.json()
networks = data['networks']
#networks = list(client.networks)
print(data)
# Out:
# {'networks': [{'company': ['ЗАО «СитиБайк»'], 'href': '/v2/networks/velobike-moscow', 'id': 'velobike-moscow', 'location': {'city': 'Moscow', 'country': 'RU', 'latitude': 55.75, 'longitude': 37.616667}, 'name': 'Velobike'}, {'company': ['Urban Infrastructure Partner'], 'href': '/v2/networks/baerum-bysykkel', 'id': 'baerum-bysykkel', 'location': {'city': 'Bærum', 'country': 'NO', 'latitude': 59.89455, 'longitude': 10.546343}, 'name': 'Bysykkel'}, {'company': ['Comunicare S.r.l.'], 'href': '/v2/networks/bicincitta-siena', 'id': 'bicincitta-siena', 'location': {'city': 'Siena', 'country': 'IT', 'latitude': 43.3186, 'longitude': 11.3306}, 'name': 'Bicincittà', 'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=202'}, {'company': ['Cyclopolis Systems'], 'href': '/v2/networks/cyclopolis-maroussi', 'id': 'cyclopolis-maroussi', 'location': {'city': 'Maroussi', 'country': 'GR', 'latitude': 38.0568722388, 'longitude': 23.8083299536}, 'name': 'Cyclopolis'}, {'company': ['Groundwork', '
# ...

# %%
for networks in data['networks']:
    print(networks['name']) #shows dictionary 
    
   #'Bicincittà': 41,'Cyclopolis': 11,
# Out:
# Velobike
# Bysykkel
# Bicincittà
# Cyclopolis
# Cycle Hire
# Cyclopolis
# Bicincittà
# Cyclopolis
# Cyclopolis
# Bicincittà
# Cyclopolis
# Cyclopolis
# Cyclopolis
# Cyclopolis
# Bicincittà
# Cyclopolis
# Cyclopolis
# Bicincittà
# Cyclopolis
# Bicincittà
# Bicincittà
# Bicincittà
# Coca-Cola Zero® Bikes
# Coca-Cola Zero® Bikes
# Pun Pun Bike Share
# Coca-Cola Zero® Bikes
# BBBike
# Bicincittà
# Bydgoski rower aglomeracyjny
# Santander Cycles
# WE-cycle
# Bicincittà
# WOW Citybike
# StadtRAD Hamburg'
# Tigullionbike
# ARbike
# Velobike
# Vélib' Métropole
# Ascoli Piceno
# BiGi
# Girocleta
# Alba
# BikeMi
# Biella
# Chivasso
# Bizi
# EcoBici
# Bici in Busto
# Velo Antwerpen
# Cuneo
# Malmö by bike
# Bici las Condes
# BiciMAD
# EasyBike
# FRee Bike sharing
# EasyBike
# EasyBike
# lecce
# EasyBike
# EasyBike
# Manerba in Bici
# EasyBike
# EasyBike
# EasyBike
# EasyBike
# Mar e Bici
# EasyBike
# EasyBike
# Novara
# EasyBike
# EasyBike
# EasyBike
# ThessBike
# AthensBikes
# GoodBike
# ...

# %%
a = ["Velobike", "Bysykkel", "Bicincittà", "Cyclopolis", "Cycle Hire", "Cyclopolis", "Bicincittà", "Cyclopolis", "Cyclopolis", "Bicincittà", "Cyclopolis", "Cyclopolis", "Cyclopolis", "Cyclopolis", "Bicincittà", "Cyclopolis", "Cyclopolis", "Bicincittà", "Cyclopolis", "Bicincittà", "Bicincittà", "Bicincittà", "Coca-Cola Zero® Bikes", "Coca-Cola Zero® Bikes", "Pun Pun Bike Share", "Coca-Cola Zero® Bikes", "BBBike", "Bicincittà", "Bydgoski rower aglomeracyjny", "Santander Cycles", "WE-cycle", "Bicincittà", "WOW Citybike", "StadtRAD Hamburg'", "Tigullionbike", "ARbike", "Velobike", "Vélib' Métropole", "Ascoli Piceno", "BiGi", "Girocleta", "Alba", "BikeMi", "Biella", "Chivasso", "Bizi", "EcoBici", "Bici in Busto", "Velo Antwerpen", "Cuneo", "Malmö by bike", "Bici las Condes", "BiciMAD", "EasyBike", "FRee Bike sharing", "EasyBike", "EasyBike", "lecce", "EasyBike", "EasyBike", "Manerba in Bici", "EasyBike", "EasyBike", "EasyBike", "EasyBike", "Mar e Bici", "EasyBike", "EasyBike", "Novara", "EasyBike", "EasyBike", "EasyBike", "ThessBike", "AthensBikes", "GoodBike", "CicloSampa", "Bicicoruña", "BiciFerrolTerra", "Curtin Bike Share", "Monash BikeShare", "Mi Muovo in Bici", "Bixi", "Mi Muovo in Bici", "Bike Share Toronto", "SoBi", "ArborBike", "Pavia in bici", "Bici Perugia", "Austin B-cycle", "Bike Chattanooga", "Mi Muovo in Bici", "Pinerolo", "BIKETOWN", "Mi Muovo in Bici", "BRiteBikes", "Boise GreenBike", "Boulder B-cycle", "Mi Muovo in Bici", "Broward B-cycle", "Bublr Bikes", "Reddy Bike Share", "Capital BikeShare", "Charlotte B-cycle", "Saluzzo", "Cincy Red Bike", "Savigliano", "Citi Bike", "Coast Bike Share", "Terni", "CoGo", "Denver B-cycle", "Divvy", "Tirano in Bici", "El Paso B-cycle", "Fort Worth Bike Sharing", "Udine", "Great Rides Bike Share", "GREENbike", "Grid Bike Share", "Heartland B-cycle", "Houston B-cycle", "Blue Bikes", "Ustica", "Indego", "Indiana Pacers Bikeshare", "Juice", "BICI&CO", "B-cycle", "Link", "B-cycle", "Metro Bike Share", "Mountain Rides Bike Share", "Nice Ride", "Speziainbici", "SWell Cycle", "Share-a-Bull Bikes", "Venezia", "SoBi", "Spartanburg BCycle", "Topeka Metro Bikes", "[TO]BIKE", "UBike", "Relay Bike Share", "BikeRecife", "BikeSampa", "BikeRio", "BikeSalvador", "BikePOA", "MIBICI", "Just Eat Cycles", "Melbourne Bike Share", "Libélo", "BikeSantiago", "Bysykkel", "Bysykkel", "Bysykkel", "LE vélo Star", "V³", "V'Lille", "IDECycle", "Bicialtea", "Bicidorm", "SaforBici", "Ciclopi", "Gbici", "MuyBici", "PonfeMobi", "VaiBike", "Cagliari", "Ecobici", "Gira", "Gimme Bike", "cy'clic", "Vélô", "Veloh", "Valenbisi", "Sellero", "Lundahoj", "Ugento", "Tusbic", "Vélam", "Bysykkel", "VéloCité", "Prata Camportaccio", "Vélo'V", "Bicikelj", "Civitavecchia", "Sevici", "LonganoinBici", "Li bia velo", "vélOstan'lib", "Cristolib", "villo", "Cassano d'Adda", "Velo2", "Cyclocity", "cyclocity", "Bianzone in Bici", "LeVélo", "Bicloo", "VéloCité", "Rietinbici", "dublinbikes", "Bicipalma", "ADCB Bikeshare", "Castellucchio", "Vélo Bleu", "NotoinBici", "Enna", "Pordenone", "Vél'in", "Carbonia", "Cluj Bike", "MoBike", "Integrabike", "Scegli in Bici", "RiviBike", "e.motion", "DukeBike", "Bicing", "Baksi", "Baksi", "e.motion", "Isbike", "Baksi", "City bikes", "Monopoli BIKE", "Föli-fillari", "bicimia", "Tel-O-Fun", "Andria in Bici", "WhiteBikes", "Slovnaft BAjk", "Cykl", "Bicykle za dobré skutky", "Wavelo", "BicinQuartucciu", "MVGmeinrad", "EnCicla", "Olbia Bike", "Mobi", "Savona", "C.vélo", "VéliVert", "BrindisiByBike", "Vélopop", "Batumvelo", "Tradate", "BikeBH", "BikePetrolina", "JesinBici", "nbici", "BikeBrasilia", "GynDebike", "Treviso", "Bicicletar", "CajuBike", "Bike Belém", "Sondrio", "BikeSantos", "Vercelli", "Portofino Park and Bike", "Mi bici tu bici", "Citi Bike Miami", "Meglio in Bici", "Des Moines B-cycle", "Comunità Montana Valli dell'Ossola", "Greenville B-cycle", "Bicincittà", "Bicincittà", "Bicincittà", "Mi Muovo in Bici", "Bicincittà", "Bicincittà", "Bicincittà", "Mi Muovo in Bici", "Bicincittà", "Bicincittà", "Parkinbici", "Bicincittà", "Bicincittà", "Bicincittà", "Mi Muovo in bici", "Bicincittà", "Mi Muovo in Bici", "Bicincittà", "Bicincittà", "Bicincittà", "We Love bike", "Bicincittà", "Bicincittà", "Bicincittà", "Bicincittà", "Bicincittà", "Bicincittà", "Bicincittà", "Bicincittà", "Bicincittà", "Bicincittà", "Mi Muovo in bici", "Bicincittà", "Bicincittà", "Mi Muovo in Bici", "Bicincittà", "Bicincittà", "Bicincittà", "Bicincittà", "BiciSchio", "Mi Muovo in bici", "Nextbike", "Nextbike", "VISA", "KVB Rad", "Fächerrad", "Burgenland", "Nextbike", "Nextbike", "Nextbike", "Nextbike", "Nextbike", "SiXT", "metropolradruhr", "metropolradruhr", "metropolradruhr", "metropolradruhr", "metropolradruhr", "metropolradruhr", "metropolradruhr", "metropolradruhr", "metropolradruhr", "metropolradruhr", "Nextbike", "Nextbike", "Nextbike", "WRM", "Nextbike", "Nextbike", "Nextbike", "Nextbike", "Nextbike", "UsedomRad", "Nextbike", "SWA Rad", "Nextbike", "PRM", "Nextbike", "VRN", "VRN", "Stadtrad", "Nextbike", "VETURILO", "Nextbike", "Nextbike", "Nextbike", "Nextbike", "BelfastBikes", "Nextbike", "Grad Šibenik", "LRM Lublin", "Healthy Ride", "GRM Grodzisk", "Nextbike", "VRN", "VRN", "Nextbike", "Nextbike", "Nextbike", "Nextbike", "Grad Karlovac", "Grad Slavonski Brod", "Santander Cycles MK", "Nextbike", "Grad Makarska", "Općina Brinje", "Grad Zadar", "VRN", "Grad Ivanić-Grad", "Bike_S SRM", "Nextbike", "Co-bikes", "Nextbike", "Nextbike", "Stacje Sponsorskie Nextbike Veturilo", "bike4all", "Chartered Bike", "WK-Bike", "VRN", "Nextbike", "Nextbike", "Nextbike", "VRN", "Stacje Sponsorskie Nextbike PRM", "Nextbike", "Nextbike", "VRN", "Sitycleta", "Grad Velika Gorica", "Grad Sisak", "Kołobrzeski Rower Miejski", "Grad Metković", "Nextbike", "Nextbike", "Nextbike", "Arriva", "Nextbike", "MOL Bubi", "Nextbike", "Rower Miejski Szamotuły", "Nextbike", "VRN", "Piaseczyński Rower Miejski", "Nextbike", "Nextbike", "Nextbike", "Nextbike", "Nextbike", "VRN", "Nextbike", "VRN", "VRN", "Nextbike", "VRN", "Nextbike", "Santander Cycles", "Nextbike", "BL bike", "Nextbike", "Berlin-Buch Campus", "Nextbike", "Zielonogórski Rower Miejski", "Santander Mönchengladbach", "NomagoBikes", "BilbonBizi", "NomagoBikes", "Nextbike", "BikeKia", "Koniński Rower Miejski", "Nextbike", "Nextbike", "Tarnowski Rower Miejski", "Koło Marek", "Rowerowe Łódzkie", "Rowerowe Łódzkie", "Rowerowe Łódzkie", "Rowerowe Łódzkie", "Rowerowe Łódzkie", "Rowerowe Łódzkie", "Rowerowe Łódzkie", "Rowerowe Łódzkie", "Rowerowe Łódzkie", "Rowerowe Łódzkie", "Frelo", "BiTS", "MOBIbike", "Velobike", "Velobike", "Nextbike", "Almatybike", "Shymkentbike", "Bay Wheels", "Vélocéo", "MonaBike", "Tarbes et Lourdes vls", "ZébullO", "Velect’in", "Rubis'Vélo", "Vélo tanlib", "Marseillan vélo libre-service", "VIA Vélo", "vélYcéo", "Vélo'Cité", "Le Vélo Baulois", "Le Marcel", "Tempo Vélo", "semo", "Cyclovis", "Chantrerie VLS (Captain Bike)", "Saclay VLS (Captain Bike)", "Vël'Ok", "WienMobil Rad", "Verona Bike", "Sprottenflotte", "Vélomagg", "RTC Bike Share", "Spokies BCycle", "Alsa nextbike León", "Vélhop", "Optymo", "BIKER Białystok Poland", "nextbike Prostejov", "Katowice Bike Poland", "nextbike Romania", "Grad Vukovar (Croatia)", "System Rowerów Miejskich w Pszczynie Poland", "Tyski Rower Miejski Poland", "Częstochowski Rower Miejski Poland", "Pruszkowski Rower Miejski Poland", "OK Bike Poland", "Grad Zaprešić (Croatia)", "Porec bike share (Croatia)", "Kaliski Rower Miejski Poland", "Rower Miejski w Ostrowie Wielkopolskim Poland", "Santander Cycles - Brunel", "Koszaliński Rower Miejski Poland", "Sosnowiecki Rower Miejski Poland", "Pobiedziski Rower Gminny Poland", "Siemianowicki Rower Miejski Poland", "Piotrkowski Rower Miejski Poland", "Płocki Rower Miejski (PRM) Poland", "Płocki Rower Miejski (PRM) Poland", "Otwocki Rower Miejski Poland", "Ciechanowski Rower Miejski Poland", "Żyrardowski Rower Miejski Poland", "SAP Walldorf", "Općina Dugopolje (Croatia)", "Općina Pitomača (Croatia)", "Nomago Bikes - LJUBLJANA", "System Roweru Gminnego Poland", "RVK", "Partnerzy Nextbike Polska", "wupsiRad Leverkusen", "Lovesharing (Canary Islands)", "Lovesharing (Canary Islands)", "Lovesharing (Canary Islands)", "VAG_Rad", "Grad Split (Croatia)", "Grad Split (Croatia)", "Grad Split (Croatia)", "Grad Split (Croatia)", "Grad Split (Croatia)", "Grad Split (Croatia)", "Grad Split (Croatia)", "Grad Split (Croatia)", "Grad Split (Croatia)", "nextbike Ostrava", "nextbike Ostrava", "nextbike Ostrava", "Luboński Rower Miejski Poland", "ibizi", "sprintRAD", "Komornicki System Rowerowy Poland", "nextbike Havířov", "nextbike Berounsko", "Graben - ready4green", "Oleski Rower Miejski Poland", "Styr & Ställ (Sweden, Göteborg)", "Nibelungen-Bike", "nextbike Brno", "nextbike Brno", "nextbike Praha", "nextbike Praha", "nextbike Olomouc", "nextbike Kladno", "nextbike Opava", "meinSiggi", "YOY - San Luis Potosi", "YOY - San Luis Potosi", "Bergisches e-Bike", "nextbike Pardubice", "nextbike Hradec Králové", "nextbike Mladoboleslavsko", "nextbike Mladoboleslavsko", "Oeynrad", "RSVG-Bike", "city bike Linz", "Drobeta Velopark", "Nomago Bikes - GO2GO", "Saturn", "nextbike Frýdek-Místek", "nextbike Uherské Hradiště", "nextbike Zlín", "nextbike Krnov", "Eifel e-Bike", "nextbike Rychnovsko", "nextbike Písek", "nextbike Jihlava", "Nomago Bikes - ZANAPREJ", "Rower Powiatowy Sokołów Podlaski", "nextbike Bergamo", "eMobi (Croatia)", "ARVAL", "OLi-Bike", "BBK Klimabizi", "MV-Rad", "MV-Rad", "StadtRad Greifswald", "nextbike Dvůr Králové", "VVT REGIORAD Tirol", "VVT REGIORAD Tirol", "Chełmski Rower", "nextbike Vrchlabí", "WinsenRad", "ŁoKeR - Łomża", "Nomago Bikes - KRANJSKA GORA", "Nomago Bikes - PORTOROZ", "VRN", "Velocity", "àVélo", "Accès Vélo", "Vilvolt", "VeloBaie", "Donkey Republic - Gent", "MBajk", "PubliBike Zürich", "PubliBike Sierre", "PubliBike Région de Nyon", "PubliBike Bern", "PubliBike Sottoceneri (TI)", "PubliBike Fribourg", "PubliBike Lausanne-Morges", "PubliBike Sion"]

# %%
Counter(a)

# %%
import collections 


c = collections.Counter(a)
print(c)
print(c.most_common()) # to sort values from highest to lowest
# Out:
# Counter({'Nextbike': 59, 'Bicincittà': 41, 'EasyBike': 14, 'VRN': 14, 'Cyclopolis': 11, 'metropolradruhr': 10, 'Rowerowe Łódzkie': 10, 'Mi Muovo in Bici': 9, 'Grad Split (Croatia)': 9, 'Bysykkel': 5, 'Velobike': 4, 'Coca-Cola Zero® Bikes': 3, 'Baksi': 3, 'Mi Muovo in bici': 3, 'Lovesharing (Canary Islands)': 3, 'nextbike Ostrava': 3, 'Santander Cycles': 2, 'SoBi': 2, 'B-cycle': 2, 'VéloCité': 2, 'e.motion': 2, 'NomagoBikes': 2, 'Płocki Rower Miejski (PRM) Poland': 2, 'nextbike Brno': 2, 'nextbike Praha': 2, 'YOY - San Luis Potosi': 2, 'nextbike Mladoboleslavsko': 2, 'MV-Rad': 2, 'VVT REGIORAD Tirol': 2, 'Cycle Hire': 1, 'Pun Pun Bike Share': 1, 'BBBike': 1, 'Bydgoski rower aglomeracyjny': 1, 'WE-cycle': 1, 'WOW Citybike': 1, "StadtRAD Hamburg'": 1, 'Tigullionbike': 1, 'ARbike': 1, "Vélib' Métropole": 1, 'Ascoli Piceno': 1, 'BiGi': 1, 'Girocleta': 1, 'Alba': 1, 'BikeMi': 1, 'Biella': 1, 'Chivasso': 1, 'Bizi': 1, 'EcoBici': 1, 'Bici in Busto': 1, 'Velo Antwerpen': 1, 'Cuneo': 1, 'Malmö
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np


bars = ["Nextbike", "Bicincittà", "EasyBike", "VRN", "Cyclopolis", "metropolradruhr", "Rowerowe Łódzkie", "Mi Muovo in Bici", "Grad Split (Croatia)"]
height = [59, 41, 14, 14, 11, 10, 10, 9, 9]

y_pos = np.arange(len(bars))

plt.barh(y_pos, height,color=['pink'])

plt.yticks(y_pos, bars)

plt.show()
